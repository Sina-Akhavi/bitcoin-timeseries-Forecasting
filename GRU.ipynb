# %% [markdown]
# <a href="https://colab.research.google.com/github/Sina-Akhavi/bitcoin-timeseries-Forecasting/blob/main/GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import math
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers



# os.chdir('./sample_data')

df = pd.read_csv('BTC-USD.csv')

X_df = df.drop(['Adj Close'], axis='columns')

X_df = X_df[X_df['Date'] > '2014-09-17']
X_df = X_df[X_df['Date'] < '2020-08-01']
X_df = X_df.drop(['Open', 'High', 'Low', 'Volume'], axis='columns')
close_stock = X_df.copy()

del X_df['Date']
scaler = MinMaxScaler()
closedf = scaler.fit_transform(np.array(X_df).reshape(-1, 1))

training_size = int(len(closedf) * 0.80)
test_size = len(closedf) - training_size
train_data, test_data = closedf[0: training_size, :], closedf[training_size: len(closedf), :1]

# train_data[:5]
print('train_data shape: ', train_data.shape)
print('test_data shape: ', test_data.shape)

def create_XtrainYtrain(dataset, time_step):

  data_X, data_Y = [], []

  for i in range(len(dataset) - time_step - 1):
    a = dataset[i: (i + time_step), 0]
    data_X.append(a)
    data_Y.append(dataset[(i + time_step), 0])

  return np.array(data_X), np.array(data_Y)



time_step = 15
X_train, y_train = create_XtrainYtrain(train_data, time_step)
X_test, y_test = create_XtrainYtrain(test_data, time_step)


print('x_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('x_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)


X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print('X_train.shape: ', X_train.shape)
print('X_test.shape: ', X_test.shape)


model = models.Sequential([
layers.GRU(31, input_shape=(time_step, 1), activation='relu',return_sequences=True),
layers.GRU(31, activation='relu'),
layers.Dropout(0.5),
layers.Dense(1)
])


model.summary()

model.compile(loss="mean_squared_error", optimizer="adam")




model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test),verbose=1)
# Out:
# train_data shape:  (1715, 1)
# test_data shape:  (429, 1)
# x_train shape: (1699, 15)
# y_train shape: (1699,)
# x_test shape: (413, 15)
# y_test shape: (413,)
# X_train.shape:  (1699, 15, 1)
# X_test.shape:  (413, 15, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 15, 31)            3162
#
#  gru_1 (GRU)                 (None, 31)                5952
#
#  dropout (Dropout)           (None, 31)                0
#
#  dense (Dense)               (None, 1)                 32
#
# =================================================================
# Total params: 9146 (35.73 KB)
# Trainable params: 9146 (35.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 54/54 [==============================] - 5s 29ms/step - loss: 0.0220 - val_loss: 0.0041
# Epoch 2/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0068 - val_loss: 8.8358e-04
# Epoch 3/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 4/200
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0045 - val_loss: 0.0030
# Epoch 5/200
# 54/54 [==============================] - 2s 29ms/step - loss: 0.0057 - val_loss: 0.0024
# Epoch 6/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 7/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 8/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 9/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 10/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 8.8377e-04
# Epoch 11/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 12/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 13/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 14/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0040 - val_loss: 0.0035
# Epoch 15/200
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 16/200
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 17/200
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 18/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0031 - val_loss: 5.0958e-04
# Epoch 19/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0035 - val_loss: 4.9780e-04
# Epoch 20/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 21/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0038 - val_loss: 7.0687e-04
# Epoch 22/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0039 - val_loss: 4.6355e-04
# Epoch 23/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0035 - val_loss: 8.1247e-04
# Epoch 24/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 25/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0034 - val_loss: 9.0222e-04
# Epoch 26/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 27/200
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 28/200
# 54/54 [==============================] - 2s 29ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 29/200
# 54/54 [==============================] - 2s 28ms/step - loss: 0.0037 - val_loss: 5.6351e-04
# Epoch 30/200
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0040 - val_loss: 8.1586e-04
# Epoch 31/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0038 - val_loss: 8.8925e-04
# Epoch 32/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0035 - val_loss: 6.7834e-04
# Epoch 33/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 34/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 8.4938e-04
# Epoch 35/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 36/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 37/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0034 - val_loss: 6.1687e-04
# Epoch 38/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0033 - val_loss: 4.2212e-04
# Epoch 127/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 128/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0034 - val_loss: 5.2525e-04
# Epoch 129/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 130/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0033 - val_loss: 7.4978e-04
# Epoch 131/200
# 54/54 [==============================] - 2s 28ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 132/200
# 54/54 [==============================] - 2s 29ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 133/200
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 134/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 5.2103e-04
# Epoch 135/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0034 - val_loss: 3.4930e-04
# Epoch 136/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 137/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0033 - val_loss: 3.7599e-04
# Epoch 138/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 139/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0033 - val_loss: 5.9166e-04
# Epoch 140/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 141/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0033 - val_loss: 3.4295e-04
# Epoch 142/200
# 54/54 [==============================] - 2s 28ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 143/200
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0037 - val_loss: 5.1324e-04
# Epoch 144/200
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 3.8806e-04
# Epoch 145/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 146/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0033 - val_loss: 8.1224e-04
# Epoch 147/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 148/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 149/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 9.1199e-04
# Epoch 150/200
# 54/54 [==============================] - 2s 30ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 151/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0038 - val_loss: 6.2747e-04
# Epoch 152/200
# 54/54 [==============================] - 3s 48ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 153/200
# 54/54 [==============================] - 3s 48ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 154/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0032 - val_loss: 6.9443e-04
# Epoch 155/200
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0036 - val_loss: 9.2597e-04
# Epoch 156/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0038 - val_loss: 5.5264e-04
# Epoch 157/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0033 - val_loss: 9.6280e-04
# Epoch 158/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0041 - val_loss: 9.8619e-04
# Epoch 159/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0035 - val_loss: 9.3963e-04
# Epoch 160/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 161/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 162/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0032 - val_loss: 9.2348e-04
# Epoch 163/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0035 - val_loss: 3.7008e-04
# Epoch 164/200
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0038 - val_loss: 4.4995e-04
# Epoch 165/200
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0033 - val_loss: 4.2866e-04
# Epoch 166/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 167/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 168/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0029 - val_loss: 0.0055
# Epoch 169/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0036 - val_loss: 8.5480e-04
# Epoch 170/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0035 - val_loss: 9.9236e-04
# Epoch 171/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 172/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 173/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0035 - val_loss: 5.0001e-04
# Epoch 174/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 175/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 176/200
# 54/54 [==============================] - 2s 29ms/step - loss: 0.0031 - val_loss: 7.3624e-04
# Epoch 177/200
# 54/54 [==============================] - 2s 32ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 178/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0035 - val_loss: 8.7213e-04
# Epoch 179/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0036 - val_loss: 7.9758e-04
# Epoch 180/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 181/200
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0039 - val_loss: 6.2598e-04
# Epoch 182/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 183/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 184/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0037 - val_loss: 9.2570e-04
# Epoch 185/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0031 - val_loss: 6.2054e-04
# Epoch 186/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 187/200
# 54/54 [==============================] - 2s 28ms/step - loss: 0.0030 - val_loss: 8.2273e-04
# Epoch 188/200
# 54/54 [==============================] - 3s 54ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 189/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0031 - val_loss: 7.4513e-04
# Epoch 190/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 191/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0032 - val_loss: 6.4554e-04
# Epoch 192/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0040 - val_loss: 6.9450e-04
# Epoch 193/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0037 - val_loss: 4.3537e-04
# Epoch 194/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0034 - val_loss: 9.9507e-04
# Epoch 195/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 8.9856e-04
# Epoch 196/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 197/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0030 - val_loss: 7.7798e-04
# Epoch 198/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0030 - val_loss: 6.0137e-04
# Epoch 199/200
# 54/54 [==============================] - 2s 29ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 200/200
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0033 - val_loss: 5.9046e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# do the inverse transformation

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

original_ytrain = scaler.inverse_transform(y_train.reshape(-1, 1))
original_ytest = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 54/54 [==============================] - 1s 6ms/step
# 13/13 [==============================] - 0s 6ms/step

# %%
def calculate_mape(actual, predicted) -> float:

    # Convert actual and predicted
    # to numpy array data type if not already
    if not all([isinstance(actual, np.ndarray),
                isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)

    # Calculate the MAPE value and return
    return round(np.mean(np.abs((
      actual - predicted) / actual)) * 100, 2)



print('Train Data RMSE: ', math.sqrt(mean_squared_error(original_ytrain, train_predict)))
print('Train Data MSE: ', mean_squared_error(original_ytrain, train_predict))
print('Train Data MAE: ', mean_absolute_error(original_ytrain, train_predict))
print('Train MAPE=', calculate_mape(original_ytrain, train_predict))
print('----------------------------------------------------------')
print('Test Data RMSE: ', math.sqrt(mean_squared_error(original_ytest, test_predict)))
print('Test Data MSE: ', mean_squared_error(original_ytest, test_predict))
print('Test Data MAE: ', mean_absolute_error(original_ytest, test_predict))
print('Test MAPE=', calculate_mape(original_ytest, test_predict))
# Out:
# Train Data RMSE:  361.9934912779993
# Train Data MSE:  131039.28772763496
# Train Data MAE:  261.8696650552393
# Train MAPE= 41.96
# ----------------------------------------------------------
# Test Data RMSE:  469.4454732585478
# Test Data MSE:  220379.0523629419
# Test Data MAE:  363.9476368460957
# Test MAPE= 4.04

# %%
# shift train predictions for plotting
from itertools import cycle
import plotly.express as px

look_back = time_step
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :] = train_predict
print("Train Predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1: len(closedf)-1, :] = test_predict
print("Test Predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price', 'Train Predicted close price',  'Test Predicted close price'])

plotdf = pd.DataFrame({'date': close_stock['Date'],
                       'original_close': close_stock['Close'],
                       'train_predicted_close': trainPredictPlot.reshape(1, -1)[0].tolist(),
                       'test_predicted_close': testPredictPlot.reshape(1, -1)[0].tolist()})

fig = px.line(plotdf, x=plotdf['date'], y=[plotdf['original_close'], plotdf['train_predicted_close'], plotdf['test_predicted_close']],
              labels={'value': 'stock price', 'date': 'Data'})

fig.update_layout(title_text='Comparison between original close price vs predicted close price', plot_bgcolor='white', font_size=15,
                  font_color='black', legend_title_text='Close price')

fig.for_each_trace(lambda t: t.update(name = next(names)))
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# Train Predicted data:  (2144, 1)
# Test Predicted data:  (2144, 1)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d72dab0d-c980-46ed-8c88-87a53db73438" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d72dab0d-c980-46ed-8c88-87a53db73438")) {                    Plotly.newPlot(                        "d72dab0d-c980-46ed-8c88-87a53db73438",                        [{"hovertemplate":"variable=original_close\u003cbr\u003eData=%{x}\u003cbr\u003estock price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"original_close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Original close price","showlegend":true,"x":["2014-09-18","2014-09-19","2014-09-20","2014-09-21","2014-09-22","2014-09-23","2014-09-24","2014-09-25","2014-09-26","2014-09-27","2014-09-28","2014-09-29","2014-09-30","2014-10-01","2014-10-02","2014-10-03","2014-10-04","2014-10-05","2014-10-06","2014-10-07","2014-10-08","2014-10-09","2014-10-10","2014-10-11","2014-10-12","2014-10-13","2014-10-14","2014-10-15","2014-10-16","2014-10-17","2014-10-18","2014-10-19","2014-10-20","2014-10-21","2014-10-22","2014-10-23","2014-10-24","2014-10-25","2014-10-26","2014-10-27","2014-10-28","2014-10-29","2014-10-30","2014-10-31","2014-11-01","2014-11-02","2014-11-03","2014-11-04","2014-11-05","2014-11-06","2014-11-07","2014-11-08","2014-11-09","2014-11-10","2014-11-11","2014-11-12","2014-11-13","2014-11-14","2014-11-15","2014-11-16","2014-11-17","2014-11-18","2014-11-19","2014-11-20","2014-11-21","2014-11-22","2014-11-23","2014-11-24","2014-11-25","2014-11-26","2014-11-27","2014-11-28","2014-11-29","2014-11-30","2014-12-01","2014-12-02","2014-12-03","2014-12-04","2014-12-05","2014-12-06","2014-12-07","2014-12-08","2014-12-09","2014-12-10","2014-12-11","2014-12-12","2014-12-13","2014-12-14","2014-12-15","2014-12-16","2014-12-17","2014-12-18","2014-12-19","2014-12-20","2014-12-21","2014-12-22","2014-12-23","2014-12-24","2014-12-25","2014-12-26","2014-12-27","2014-12-28","2014-12-29","2014-12-30","2014-12-31","2015-01-01","2015-01-02","2015-01-03","2015-01-04","2015-01-05","2015-01-06","2015-01-07","2015-01-08","2015-01-09","2015-01-10","2015-01-11","2015-01-12","2015-01-13","2015-01-14","2015-01-15","2015-01-16","2015-01-17","2015-01-18","2015-01-19","2015-01-20","2015-01-21","2015-01-22","2015-01-23","2015-01-24","2015-01-25","2015-01-26","2015-01-27","2015-01-28","2015-01-29","2015-01-30","2015-01-31","2015-02-01","2015-02-02","2015-02-03","2015-02-04","2015-02-05","2015-02-06","2015-02-07","2015-02-08","2015-02-09","2015-02-10","2015-02-11","2015-02-12","2015-02-13","2015-02-14","2015-02-15","2015-02-16","2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-21","2015-02-22","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-02-28","2015-03-01","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-07","2015-03-08","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-14","2015-03-15","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-21","2015-03-22","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-28","2015-03-29","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-03","2015-04-04","2015-04-05","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-11","2015-04-12","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-18","2015-04-19","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-25","2015-04-26","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-02","2015-05-03","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-09","2015-05-10","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-1 ...
